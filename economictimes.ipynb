# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome(r"C:\Users\ChesthaS\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
url = "https://economictimes.indiatimes.com/archive.cms"
driver.get(url)

# %%
click_tag=driver.find_element_by_xpath("//*[@id='pageContent']/div[2]/table/tbody/tr[1]/td/span/div/strong/a[219]")

# %%
click=click_tag.get_attribute('href')

# %%
driver.get(click)

# %%
click1_tag=driver.find_elements_by_xpath("//*[@id='calender']/tbody/tr/td[4]/a")

# %%
datesfirst=[]
for i in click1_tag:
    datesfirst.append(i.get_attribute('href'))

# %%
datesfirst
# Out:
# ['https://economictimes.indiatimes.com/archivelist/year-2017,month-11,starttime-43040.cms',
#  'https://economictimes.indiatimes.com/archivelist/year-2017,month-11,starttime-43047.cms',
#  'https://economictimes.indiatimes.com/archivelist/year-2017,month-11,starttime-43054.cms',
#  'https://economictimes.indiatimes.com/archivelist/year-2017,month-11,starttime-43061.cms',
#  'https://economictimes.indiatimes.com/archivelist/year-2017,month-11,starttime-43068.cms']

# %%
Date=[]
Author=[]
Vertical=[]
Headline=[]
Description=[]

# %%
newsfirsturl=[]
for i in datesfirst:
    driver.get(i)
    time.sleep(5)
    newsmainpage=driver.find_elements_by_xpath("//*[@id='pageContent']/span/table[2]/tbody/tr/td[1]/ul/li/a")
    for i in newsmainpage:
        newsfirsturl.append(i.get_attribute('href'))

# %%
newsfirsturl
# Out:
# ['https://economictimes.indiatimes.com/industry/banking/finance/banking/hdfc-bank-to-expand-smartup-zones-in-bengaluru/articleshow/61376763.cms',
#  'https://economictimes.indiatimes.com/news/defence/view-little-talk-on-chinas-muscle-flexing-as-all-discuss-xi-jinping/articleshow/61376812.cms',
#  'https://economictimes.indiatimes.com/news/sports/all-eyes-on-ashish-nehra-pacer-set-to-hang-his-boots-at-home-ground/articleshow/61376991.cms',
#  'https://economictimes.indiatimes.com/news/sports/glorious-football-18-touches-48-seconds-and-no-goal/articleshow/61377179.cms',
#  'https://economictimes.indiatimes.com/industry/energy/power/danfoss-partners-to-set-up-district-cooling-pilot-project-in-india/articleshow/61377189.cms',
#  'https://economictimes.indiatimes.com/tech/ites/infosys-is-to-blame-for-gst-network-glitches-say-government-officials/articleshow/61377270.cms',
# ...

# %%
len(newsfirsturl)
# Out:
# 1050

# %%
for i in newsfirsturl:
    driver.get(i)
    time.sleep(5)
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/time")
        element1=elementt.text
        print(element1)
        Date.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/div[2]/a")
        element1=elementt.text
        print(element1)
        Author.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[1]/h1")
        element1=elementt.text
        print(element1)
        Headline.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[7]/div/span[4]/a")
        element1=elementt.text
        print(element1)
        Vertical.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[3]/div/div/h2")
        element1=elementt.text
        print(element1)
        Description.append(element1)
    except NoSuchElementException as e:
        print('-')
# Out:
# Last Updated: Nov 01, 2017, 12:09 AM IST
# Sanghamitra Kar
# HDFC Bank to expand SmartUp zones in Bengaluru
# Banking
# More than 35% of all the startup accounts opened after SmartUp launch and are based in Bengaluru, said HDFC Bank in a statement.
# Last Updated: Jul 12, 2018, 11:54 AM IST
# -
# View: Little talk on China’s muscle-flexing as all discuss Xi Jinping
# -
# The emergence of a determined and zealous nationalist figure who dreams of placing China centre-stage internationally has wide implications.
# Last Updated: Mar 01, 2018, 10:30 PM IST
# Amit Chaudhary
# India vs New Zealand first T20: All eyes on Ashish Nehra as pacer set to hang his boots at home ground
# -
# They play to win, and on merit, Nehra doesn’t command an automatic spot in the playing XI ahead of Bhuvneshwar Kumar and Jasprit Bumrah.
# Last Updated: Nov 01, 2017, 12:31 AM IST
# Indrajit Hazra
# Glorious Football: 18 touches, 48 seconds and no goal
# -
# ...

# %%
url = "https://economictimes.indiatimes.com/archive.cms"
driver.get(url)
click_tag=driver.find_element_by_xpath("//*[@id='pageContent']/div[2]/table/tbody/tr[1]/td/span/div/strong/a[219]")
click=click_tag.get_attribute('href')
driver.get(click)
click2_tag=driver.find_elements_by_xpath("//*[@id='calender']/tbody/tr/td[5]/a")
datessecound=[]
for i in click2_tag:
    datessecound.append(i.get_attribute('href'))
datessecound
newssecoundurl=[]
for i in datessecound:
    driver.get(i)
    time.sleep(5)
    newsmainpage=driver.find_elements_by_xpath("//*[@id='pageContent']/span/table[2]/tbody/tr/td[1]/ul/li/a")
    for i in newsmainpage:
        newssecoundurl.append(i.get_attribute('href'))

# %%
newssecoundurl
# Out:
# ['https://economictimes.indiatimes.com/industry/energy/power/eesl-receives-434-mn-from-global-multilateral-agencies/articleshow/61427374.cms',
#  'https://economictimes.indiatimes.com/industry/healthcare/biotech/pharmaceuticals/intas-closing-in-on-mallinckrodts-us-generics-business/articleshow/61427454.cms',
#  'https://economictimes.indiatimes.com/news/company/deals/intas-closing-in-on-mallinckrodts-us-generics-business/articleshow/61561301.cms',
#  'https://economictimes.indiatimes.com/industry/services/retail/walmart-opens-its-first-india-dark-store-in-bhiwandi/articleshow/61427512.cms',
#  'https://economictimes.indiatimes.com/markets/stocks/earnings/radio-mirchi-ebitda-rises-22-8-to-rs-22-8-crore-in-q2/articleshow/61427551.cms',
#  'https://economictimes.indiatimes.com/tech/internet/reliance-communications-may-stay-mvno-post-2g-3g-voice-exit/articleshow/61427632.cms',
# ...

# %%
len(newssecoundurl)
# Out:
# 1046

# %%
for i in newssecoundurl:
    driver.get(i)
    time.sleep(5)
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/time")
        element1=elementt.text
        print(element1)
        Date.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/div[2]/a")
        element1=elementt.text
        print(element1)
        Author.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[1]/h1")
        element1=elementt.text
        print(element1)
        Headline.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[7]/div/span[4]/a")
        element1=elementt.text
        print(element1)
        Vertical.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[3]/div/div/h2")
        element1=elementt.text
        print(element1)
        Description.append(element1)
    except NoSuchElementException as e:
        print('-')
# Out:
# Last Updated: Nov 02, 2017, 12:12 AM IST
# Nishtha Saluja
# EESL receives $434 mn from global, multilateral agencies
# Power
# "EESL plans to commercialise segments of the energy efficiency market, which are yet unexplored and bring them to the mainstream through this funding opportunity."
# Last Updated: Nov 08, 2017, 03:48 PM IST
# Arijit Barman
# Intas closing in on Mallinckrodt’s US generics business
# Pharmaceuticals
# This comes as US President Donald Trump has declared opioid addiction a public health emergency in the US and drugmakers have found themselves under scrutiny.
# Last Updated: Nov 08, 2017, 03:48 PM IST
# Arijit Barman
# Intas closing in on Mallinckrodt’s US generics business
# Deals
# This comes as US President Donald Trump has declared opioid addiction a public health emergency in the US and drugmakers have found themselves under scrutiny.
# Last Updated: Nov 02, 2017, 12:16 AM IST
# -
# Walmart opens its first India ‘dark store’ in Bhiwandi
# Retail
# ...

# %%
url = "https://economictimes.indiatimes.com/archive.cms"
driver.get(url)
click_tag=driver.find_element_by_xpath("//*[@id='pageContent']/div[2]/table/tbody/tr[1]/td/span/div/strong/a[219]")
click=click_tag.get_attribute('href')
driver.get(click)
click3_tag=driver.find_elements_by_xpath("//*[@id='calender']/tbody/tr/td[6]/a")
datesthird=[]
for i in click3_tag:
    datesthird.append(i.get_attribute('href'))
datesthird
newsthirdurl=[]
for i in datesthird:
    driver.get(i)
    time.sleep(5)
    newsmainpage=driver.find_elements_by_xpath("//*[@id='pageContent']/span/table[2]/tbody/tr/td[1]/ul/li/a")
    for i in newsmainpage:
        newsthirdurl.append(i.get_attribute('href'))

# %%
datesthird
# Out:
# ['https://economictimes.indiatimes.com/archivelist/year-2017,month-11,starttime-43042.cms',
#  'https://economictimes.indiatimes.com/archivelist/year-2017,month-11,starttime-43049.cms',
#  'https://economictimes.indiatimes.com/archivelist/year-2017,month-11,starttime-43056.cms',
#  'https://economictimes.indiatimes.com/archivelist/year-2017,month-11,starttime-43063.cms']

# %%
newsthirdurl
# Out:
# ['https://economictimes.indiatimes.com/news/politics-and-nation/gujarat-congress-plans-parikrama-of-7-districts-to-draft-peoples-manifesto/articleshow/61473578.cms',
#  'https://economictimes.indiatimes.com/industry/services/hotels-/-restaurants/hvs-hives-off-non-core-services-to-new-entity/articleshow/61473611.cms',
#  'https://economictimes.indiatimes.com/small-biz/policy-trends/home-services-startups-like-urbanclap-quikr-and-housejoy-reel-under-big-gst-shock/articleshow/61473689.cms',
#  'https://economictimes.indiatimes.com/news/international/world-news/hit-list-exposes-russian-hacking-beyond-us-elections/articleshow/61473730.cms',
#  'https://economictimes.indiatimes.com/news/international/business/production-is-still-hell-as-gigafactory-delays-tesla-model-3-elon-musk/articleshow/61473870.cms',
#  'https://economictimes.indiatimes.com/opinion/interviews/ad-spend-here-can-return-to-12-15-growth-kelly-clark-global-ceo-groupm/articleshow/61473925.cms',
# ...

# %%
len(newsthirdurl)
# Out:
# 744

# %%
url = "https://economictimes.indiatimes.com/archive.cms"
driver.get(url)
click_tag=driver.find_element_by_xpath("//*[@id='pageContent']/div[2]/table/tbody/tr[1]/td/span/div/strong/a[219]")
click=click_tag.get_attribute('href')
driver.get(click)
click4_tag=driver.find_elements_by_xpath("//*[@id='calender']/tbody/tr/td[7]/a")
datesfourth=[]
for i in click4_tag:
    datesfourth.append(i.get_attribute('href'))
datesfourth
newsfourthurl=[]
for i in datesfourth:
    driver.get(i)
    time.sleep(5)
    newsmainpage=driver.find_elements_by_xpath("//*[@id='pageContent']/span/table[2]/tbody/tr/td[1]/ul/li/a")
    for i in newsmainpage:
        newsfourthurl.append(i.get_attribute('href'))

# %%
newsfourthurl
# Out:
# ['https://economictimes.indiatimes.com/news/international/world-news/the-latest-manafort-lawyer-to-challenge-search-warrant/articleshow/61499507.cms',
#  'https://economictimes.indiatimes.com/news/defence/indian-chinese-troops-in-dokalam-but-not-in-eyeball-to-eyeball-contact-general-bipin-rawat/articleshow/61499604.cms',
#  'https://economictimes.indiatimes.com/news/politics-and-nation/vikramaditya-singhs-political-journey-begins-on-a-tough-note/articleshow/61499609.cms',
#  'https://economictimes.indiatimes.com/magazines/panache/idea-does-secret-superstar-oversimplify-talent-struggle-and-perseverance/articleshow/61499704.cms',
#  'https://economictimes.indiatimes.com/news/international/world-news/us-government-renames-asia-pacific-as-indo-pacific-region-now/articleshow/61499715.cms',
#  'https://economictimes.indiatimes.com/news/politics-and-nation/reforms-pace-exciting-gst-just-one-example-japanese-ambassador/articleshow/61499718.cms',
# ...

# %%
len(newsfourthurl)
# Out:
# 433

# %%
for i in newsthirdurl:
    driver.get(i)
    time.sleep(5)
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/time")
        element1=elementt.text
        print(element1)
        Date.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/div[2]/a")
        element1=elementt.text
        print(element1)
        Author.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[1]/h1")
        element1=elementt.text
        print(element1)
        Headline.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[7]/div/span[4]/a")
        element1=elementt.text
        print(element1)
        Vertical.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[3]/div/div/h2")
        element1=elementt.text
        print(element1)
        Description.append(element1)
    except NoSuchElementException as e:
        print('-')
# Out:
# Last Updated: Nov 03, 2017, 01:37 AM IST
# CL Manoj
# Gujarat Congress plans ‘parikrama’ of 7 districts to draft ‘people’s manifesto’
# -
# The post-demonetisation/GST issues faced by traders, farm distress, unemployment and homelessness will be major areas of Congress’ interactions with the audience.
# Last Updated: Nov 03, 2017, 12:14 AM IST
# Anumeha Chaturvedi
# HVS hives off non-core services to new entity
# Hotels / Restaurants
# HVS India’s senior executives hold equity in the new entity along with the New York-headquartered firm’s CEO, Steve Rushmore Jr.
# Last Updated: Nov 03, 2017, 11:20 AM IST
# Deepshikha Sikarwar
# Home services startups like UrbanClap, Quikr and Housejoy reel under big GST shock
# -
# These services now attract goods and services tax at 18%, making them uncompetitive in comparison with neighbourhood rivals who typically get jobs based on word of mouth.
# Last Updated: Nov 03, 2017, 12:14 AM IST
# -
# Hit list exposes Russian hacking beyond US elections
# ...

# %%
for i in newsfourthurl:
    driver.get(i)
    time.sleep(5)
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/time")
        element1=elementt.text
        print(element1)
        Date.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/div[2]/a")
        element1=elementt.text
        print(element1)
        Author.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[1]/h1")
        element1=elementt.text
        print(element1)
        Headline.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[7]/div/span[4]/a")
        element1=elementt.text
        print(element1)
        Vertical.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[3]/div/div/h2")
        element1=elementt.text
        print(element1)
        Description.append(element1)
    except NoSuchElementException as e:
        print('-')
# Out:
# -
# -
# -
# -
# -
# Last Updated: Jul 12, 2018, 03:15 PM IST
# -
# Indian, Chinese troops in Dokalam, but not in eyeball-to- eyeball contact: General Bipin Rawat
# -
# General Rawat said there had been a disengagement of troops of both countries in Dokalam, where the two sides were locked in a stand-off that ended in August.
# Last Updated: Nov 04, 2017, 12:15 AM IST
# NIDHI SHARMA
# Vikramaditya Singh's political journey begins on a tough note
# -
# As he makes his debut in the November 9 polls, Singh is all set to inherit his father’s legacy. His constituency – Shimla Rural – is just the beginning.
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# Last Updated: Nov 04, 2017, 10:10 AM IST
# Vasudha Venugopal
# Reforms pace exciting; GST just one example: Japanese Ambassador
# -
# "The entire Japanese community welcomes GST as it simplifies taxation, makes transport of technology and resources easier,” he said.
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# ...

# %%
url = "https://economictimes.indiatimes.com/archive.cms"
driver.get(url)
click_tag=driver.find_element_by_xpath("//*[@id='pageContent']/div[2]/table/tbody/tr[1]/td/span/div/strong/a[219]")
click=click_tag.get_attribute('href')
driver.get(click)
click5_tag=driver.find_elements_by_xpath("//*[@id='calender']/tbody/tr/td[1]/a")[1:]
datesfifth=[]
for i in click5_tag:
    datesfifth.append(i.get_attribute('href'))
datesfifth
newsfifthurl=[]
for i in datesfifth:
    driver.get(i)
    time.sleep(5)
    newsmainpage=driver.find_elements_by_xpath("//*[@id='pageContent']/span/table[2]/tbody/tr/td[1]/ul/li/a")
    for i in newsmainpage:
        newsfifthurl.append(i.get_attribute('href'))

# %%
len(newsfifthurl)
# Out:
# 473

# %%
Author
# Out:
# ['Sanghamitra Kar',
#  'Amit Chaudhary',
#  'Indrajit Hazra',
#  'Debjoy Sengupta',
#  'Deepshikha Sikarwar',
#  'Sagar Malviya',
#  'Vasudha Venugopal',
#  'NIDHI SHARMA',
#  'Gulveen Aulakh',
#  'Gulveen Aulakh',
#  'Sachin Dave',
#  'Sachin Dave',
#  'Writankar Mukherjee',
#  'Krishna Kumar',
#  'Sharmistha Mukherjee',
#  'Sharmistha Mukherjee',
#  'Ketan Thakkar',
#  'Urmi A Goswami',
#  'Deepshikha Sikarwar',
#  'Aman Sharma',
#  'Aman Sharma',
#  'Sidhartha',
#  'Atmadip Ray',
#  'Milan Vaishnav CMT MSTA',
#  'Nandini Sanyal',
#  'Varsha Bansal',
#  'Shilpy Sinha',
#  'Rajesh Naidu',
#  'Rajesh Mascarenhas',
#  'Hakeem Irfan',
#  'Sanam Mirchandani',
#  'Deepali Gupta',
#  'Jwalit Vyas',
#  'Nishanth Vasudevan',
#  'Nishanth Vasudevan',
#  'Varsha Bansal',
#  'Jwalit Vyas',
#  'Hakeem Irfan',
#  'Joel Rebello',
#  'Sutanuka Ghosal',
#  'Ram Sahgal',
#  'Sutanuka Ghosal',
#  'Ashutosh Shyam',
#  'Pratik Bhakta',
#  'Biswarup Gooptu',
#  'Amit Mudgill',
#  'Amit Mudgill',
# ...

# %%
for i in newsfifthurl:
    driver.get(i)
    time.sleep(5)
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/time")
        element1=elementt.text
        print(element1)
        Date.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/div[2]/a")
        element1=elementt.text
        print(element1)
        Author.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[1]/h1")
        element1=elementt.text
        print(element1)
        Headline.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[7]/div/span[4]/a")
        element1=elementt.text
        print(element1)
        Vertical.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[3]/div/div/h2")
        element1=elementt.text
        print(element1)
        Description.append(element1)
    except NoSuchElementException as e:
        print('-')
# Out:
# Last Updated: Nov 06, 2017, 03:44 PM IST
# -
# Himachal Pradesh: Virbhadra Singh's son fancies his chances from father's constituency
# -
# The Congress in Himachal chose to make an exception to its “one family, one ticket” dictum by announcing the nomination of Vikramaditya Singh.
# -
# -
# -
# -
# -
# Last Updated: Nov 05, 2017, 09:43 AM IST
# Prerna Katiyar
# Agra’s shoemakers, handicraft traders and silver dealers yet to recover from "DeMonic" shock
# -
# "The decision (note ban) was right but preparation and implementation were poor. Then GST added salt to our wounds. It is like a patient having to deal with two serious illnesses."
# Last Updated: Nov 05, 2017, 09:43 AM IST
# Prerna Katiyar
# Agra’s shoemakers, handicraft traders and silver dealers yet to recover from "DeMonic" shock
# -
# "The decision (note ban) was right but preparation and implementation were poor. Then GST added salt to our wounds. It is like a patient having to deal with two serious illnesses."
# ...

# %%
url = "https://economictimes.indiatimes.com/archive.cms"
driver.get(url)
click_tag=driver.find_element_by_xpath("//*[@id='pageContent']/div[2]/table/tbody/tr[1]/td/span/div/strong/a[219]")
click=click_tag.get_attribute('href')
driver.get(click)
click6_tag=driver.find_elements_by_xpath("//*[@id='calender']/tbody/tr/td[2]/a")[1:]
datessixth=[]
for i in click6_tag:
    datessixth.append(i.get_attribute('href'))
datessixth
newssixthurl=[]
for i in datessixth:
    driver.get(i)
    time.sleep(5)
    newsmainpage=driver.find_elements_by_xpath("//*[@id='pageContent']/span/table[2]/tbody/tr/td[1]/ul/li/a")
    for i in newsmainpage:
        newssixthurl.append(i.get_attribute('href'))

# %%
for i in newssixthurl:
    driver.get(i)
    time.sleep(5)
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/time")
        element1=elementt.text
        print(element1)
        Date.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/div[2]/a")
        element1=elementt.text
        print(element1)
        Author.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[1]/h1")
        element1=elementt.text
        print(element1)
        Headline.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[7]/div/span[4]/a")
        element1=elementt.text
        print(element1)
        Vertical.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[3]/div/div/h2")
        element1=elementt.text
        print(element1)
        Description.append(element1)
    except NoSuchElementException as e:
        print('-')
# Out:
# -
# -
# -
# -
# -
# Last Updated: Nov 08, 2017, 10:49 AM IST
# Aman Sharma
# Data shows Rs 17,000 crore deposited and withdrawn by 35,000 companies post demonetisation
# Policy
# One such company had a negative opening balance in its bank account on November 8. but deposited and withdrew as much as Rs 2484 cr post demonetisation.
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# Last Updated: Nov 06, 2017, 12:16 AM IST
# Sanjay Singh
# Bihar CM Nitish Kumar focuses on smooth running of government, liquor ban remains top agenda
# -
# The most visible change in his first 100 days is that he has been able to review the performance of almost every department in an expeditious manner.
# Last Updated: Nov 06, 2017, 12:17 AM IST
# Vatsala Gaur
# Hindalco eyeing high-speed rail and defence segments: MD Satish Pai
# -
# In auto, we are looking at organic expansion in two places: the US and Asia. The US will probably be the first place, said Hindalco MD.
# Last Updated: Nov 06, 2017, 12:17 AM IST
# ...

# %%
url = "https://economictimes.indiatimes.com/archive.cms"
driver.get(url)
click_tag=driver.find_element_by_xpath("//*[@id='pageContent']/div[2]/table/tbody/tr[1]/td/span/div/strong/a[219]")
click=click_tag.get_attribute('href')
driver.get(click)
click7_tag=driver.find_elements_by_xpath("//*[@id='calender']/tbody/tr/td[3]/a")[1:]
datesseventh=[]
for i in click7_tag:
    datesseventh.append(i.get_attribute('href'))
datesseventh
newssevenurl=[]
for i in datesseventh:
    driver.get(i)
    time.sleep(5)
    newsmainpage=driver.find_elements_by_xpath("//*[@id='pageContent']/span/table[2]/tbody/tr/td[1]/ul/li/a")
    for i in newsmainpage:
        newssevenurl.append(i.get_attribute('href'))

# %%
for i in newssevenurl:
    driver.get(i)
    time.sleep(5)
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/time")
        element1=elementt.text
        print(element1)
        Date.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[2]/div/div[1]/div[2]/a")
        element1=elementt.text
        print(element1)
        Author.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[1]/h1")
        element1=elementt.text
        print(element1)
        Headline.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[7]/div/span[4]/a")
        element1=elementt.text
        print(element1)
        Vertical.append(element1)
    except NoSuchElementException as e:
        print('-')
    try:
        elementt=driver.find_element_by_xpath("/html/body/main/div[10]/div/div[1]/div[3]/div/div/h2")
        element1=elementt.text
        print(element1)
        Description.append(element1)
    except NoSuchElementException as e:
        print('-')
# Out:
# Last Updated: Nov 07, 2017, 12:12 AM IST
# -
# Everstone to acquire Kenstar from Videocon
# Durables
# The deal, which has been running for a year now, had seen suitors such as Orient Electric, Symphony, Havells, Crompton Greaves and Voltas.
# Last Updated: Nov 07, 2017, 12:07 AM IST
# -
# MS Dhoni excels beyond statistics
# -
# Dhoni is no longer the marauder he once was in the T20 format, but he survives in the ODI arena on sheer willpower.
# -
# -
# -
# -
# -
# Last Updated: Nov 07, 2017, 12:15 AM IST
# Gulveen Aulakh
# Foxconn India eyes space in Nokia SEZ to boost production
# -
# Company is exploring the area for housing plants for its clients like Nokia and Xiaomi, which are growing rapidly and will require more production capacity in the coming quarters.
# Last Updated: Nov 07, 2017, 12:20 AM IST
# Shilpy Sinha
# Third party motor insurance is the new cash cow
# -
# ...

# %%
len(Date)
# Out:
# 3876

# %%
len(Author)
# Out:
# 1612

# %%
len(Vertical)
# Out:
# 2217

# %%
len(Headline)
# Out:
# 3876

# %%
len(Description)
# Out:
# 3785

# %%
Date=Date[:1612]

# %%
len(Date)
# Out:
# 1612

# %%
Author=Author[:1612]
print(len(Author))
Vertical=Vertical[:1612]
print(len(Vertical))
Headline=Headline[:1612]
print(len(Headline))
Description=Description[:1612]
print(len(Description))
# Out:
# 1612
# 1612
# 1612
# 1612

# %%
economictimes=pd.DataFrame({})
economictimes['Date']=Date
economictimes['Author']=Author
economictimes['Vertical']=Vertical
economictimes['Headline']=Headline
economictimes['Description']=Description

# %%
economictimes
# Out:
#                                           Date               Author  \
# 0     Last Updated: Nov 01, 2017, 12:09 AM IST      Sanghamitra Kar
# 1     Last Updated: Jul 12, 2018, 11:54 AM IST       Amit Chaudhary
# 2     Last Updated: Mar 01, 2018, 10:30 PM IST       Indrajit Hazra
# 3     Last Updated: Nov 01, 2017, 12:31 AM IST      Debjoy Sengupta
# 4     Last Updated: Nov 01, 2017, 12:47 AM IST  Deepshikha Sikarwar
# ...                                        ...                  ...
# 1607  Last Updated: Nov 03, 2017, 08:54 AM IST         Amit Mudgill
# 1608  Last Updated: Nov 03, 2017, 09:03 AM IST           Romit Guha
# 1609  Last Updated: Nov 03, 2017, 08:57 AM IST         Chhavi Tyagi
# 1610  Last Updated: Nov 03, 2017, 09:00 AM IST      Brinda Dasgupta
# 1611  Last Updated: Nov 03, 2017, 09:16 AM IST        Pratik Bhakta
#
#         Vertical                                           Headline  \
# 0        Banking     HDFC Bank to expand SmartUp zones in Bengaluru
# ...
