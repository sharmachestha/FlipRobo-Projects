# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome(r"C:\Users\ChesthaS\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
url = "https://www.cars24.com/buy-used-cars-kolkata/?itm_source=Cars24Website&itm_medium=sticky_header"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
driver.get(url)

# %%
carurls_tag=driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[4]/div[1]/div/div/a")
carurls_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="39e682385848235b73fbfdfd869bbfc6", element="a45901ac-7502-4ee9-94ef-bd9d7264924a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="39e682385848235b73fbfdfd869bbfc6", element="6a2e9c65-383e-4a51-817b-dd4ba56d7112")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="39e682385848235b73fbfdfd869bbfc6", element="0b501d0b-9afa-4c15-a0ca-44c1d5fc772f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="39e682385848235b73fbfdfd869bbfc6", element="d603acb5-0ea5-4258-9bd0-73b8276f3c38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="39e682385848235b73fbfdfd869bbfc6", element="16c949a1-ece6-4f98-85c7-472470390ff6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="39e682385848235b73fbfdfd869bbfc6", element="a461e1ae-6d2d-446f-a657-1e2fdb501abe")>,
# ...

# %%
len(carurls_tag)
# Out:
# 2342

# %%
carurls=[]
for i in carurls_tag:
    carurls.append(i.get_attribute('href'))

# %%
carurls
# Out:
# ['https://www.cars24.com/buy-used-Maruti-Swift-2021-cars-New-Delhi-1007142709/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2013-cars-New-Delhi-1055227042/',
#  'https://www.cars24.com/buy-used-Renault-TRIBER-2020-cars-Noida-1293353248/',
#  'https://www.cars24.com/buy-used-Hyundai-GRAND-I10-NIOS-2020-cars-New-Delhi-1488790147/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2014-cars-Faridabad-1057739946/',
#  'https://www.cars24.com/buy-used-Hyundai-NEW-SANTRO-2019-cars-Faridabad-1090657844/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-K10-2019-cars-Gurgaon-1004695702/',
#  'https://www.cars24.com/buy-used-Maruti-Ritz-2011-cars-New-Delhi-1129592323/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2016-cars-New-Delhi-1004882802/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2017-cars-Noida-1006047343/',
#  'https://www.cars24.com/buy-used-Tata-TIGOR-2017-cars-New-Delhi-1007322445/',
# ...

# %%
len(carurls)
# Out:
# 2342

# %%
for i in carurls_list:
    driver.get(i)
    time.sleep(5)
    try:
        carnames_tag=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div[4]/div[1]/div/div/a/div/div/div/h2")
        carnames_p=carnames_tag.text
        print(carnames_p)
        carnames.append(carnames_p)
    except NoSuchElementException as e:
        print('-')
        carnames.append('-')
    try:
        emiprice_tag=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div[4]/div[1]/div/div/a/div/div/div/strong")
        emiprice_p=emiprice_tag.text
        print(emiprice_p)
        emiprice.append(emiprice_p)
    except NoSuchElementException as e:
        print('-')
        emiprice.append('-')     
    try:
        rto_tag=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div[4]/div[1]/div/div/a/div/div/div/span")
        rto_p=rto_tag.text
        print(rto_p)
        rto.append(rto_p)
    except NoSuchElementException as e:
        print('-')
        rto.append('-')
    try:
        km_tag=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div[1]/div/ul/li[3]/strong")
        km_p=km_tag.text
        print(km_p)
        km.append(km_p)
    except NoSuchElementException as e:
        print('-')
        km.append('-')
    try:
        owner_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div[1]/div/ul/li[2]/strong")
        owner_p=owner_tags.text
        print(owner_p)
        owner.append(owner_p)
    except NoSuchElementException as e:
        print('-')
        owner.append('-')
    try:
        yop_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div[1]/div/ul/li[9]/strong")
        yop_p=yop_tags.text
        print(yop_p)
        yop.append(yop_p)
    except NoSuchElementException as e:
        print('-')
        yop.append('-')
    try:
        fuel_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div[1]/div/ul/li[4]/strong")
        fuel_p=fuel_tags.text
        print(fuel_p)
        fuel.append(fuel_p)
    except NoSuchElementException as e:
        print('-')
        fuel.append('-')
    try:
        loc_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[4]/div/div/div/div[1]/p/span")
        loc_p=loc_tags.text
        print(loc_p)
        loc.append(loc_p)
    except NoSuchElementException as e:
        print('-')
        loc.append('-')
    try:
        acc_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div[1]/div/ul/li[1]/strong")
        acc_p=acc_tags.text
        print(acc_p)
        acc.append(acc_p)
    except NoSuchElementException as e:
        print('-')
        acc.append('-')
# Out:
# -
# -
# -
# 97,701 km
# 1st Owner
# May 2015
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 1,12,990 km
# 1st Owner
# February 2014
# Diesel
# DELHI
# Non-Accidental
# -
# -
# -
# 1,11,841 km
# 1st Owner
# -
# Diesel
# DELHI
# Non-Accidental
# -
# -
# -
# 2,13,079 km
# 1st Owner
# September 2012
# Diesel
# DELHI
# Non-Accidental
# -
# -
# -
# 1,88,007 km
# 1st Owner
# August 2016
# Diesel
# DELHI
# Non-Accidental
# -
# -
# -
# 82,016 km
# 1st Owner
# -
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 1,40,313 km
# 1st Owner
# February 2013
# Diesel
# DELHI
# Non-Accidental
# -
# -
# -
# 1,57,858 km
# 1st Owner
# January 2013
# Diesel
# DELHI
# Non-Accidental
# -
# -
# -
# 1,26,687 km
# 1st Owner
# October 2014
# Diesel
# DELHI
# Non-Accidental
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# 1,03,033 km
# 1st Owner
# December 2014
# Diesel
# DELHI
# Non-Accidental
# -
# -
# -
# 71,343 km
# 1st Owner
# -
# Diesel
# DELHI
# Non-Accidental
# -
# -
# -
# 1,10,134 km
# 1st Owner
# -
# ...

# %%
carnames
# Out:
# ['2011 Maruti Alto K10',
#  '2020 Maruti Swift',
#  '2021 Maruti Swift',
#  '2017 Maruti Alto 800',
#  '2012 Maruti Alto K10',
#  '2013 Maruti Swift',
#  '2014 Maruti Swift',
#  '2015 Hyundai Eon',
#  '2017 Datsun Redi Go',
#  '2017 Maruti Alto K10',
#  '2015 Maruti Alto 800',
#  '2020 Hyundai AURA',
#  '2014 Maruti Alto 800',
#  '2018 Hyundai Grand i10',
#  '2019 Maruti Baleno',
#  '2011 Toyota Etios',
#  '2016 Maruti Swift',
#  '2020 Maruti Baleno',
#  '2020 Maruti Alto',
#  '2017 Renault Kwid',
#  '2018 Maruti Wagon R 1.0',
#  '2012 Maruti Alto K10',
#  '2015 Honda City',
#  '2016 Maruti Alto K10',
#  '2013 Maruti Alto 800',
#  '2016 Honda Jazz',
#  '2018 Maruti Alto 800',
#  '2014 Hyundai Grand i10',
#  '2013 Maruti Alto K10',
#  '2017 Maruti Alto K10',
#  '2014 Hyundai Grand i10',
#  '2018 Maruti Alto 800',
#  '2018 Maruti Swift',
#  '2017 Maruti Alto 800',
#  '2013 Maruti Swift',
#  '2013 Maruti Swift Dzire',
#  '2012 Maruti Alto K10',
#  '2016 Maruti Ertiga',
# ...

# %%
emiprice
# Out:
# ['₹4,734/month',
#  '₹12,110/month',
#  '₹17,017/month',
#  '₹6,535/month',
#  '₹3,908/month',
#  '₹8,822/month',
#  '₹8,744/month',
#  '₹6,177/month',
#  '₹5,481/month',
#  '₹7,690/month',
#  '₹6,202/month',
#  '₹13,364/month',
#  '₹6,531/month',
#  '₹10,297/month',
#  '₹13,300/month',
#  '₹7,080/month',
#  '₹9,049/month',
#  '₹14,744/month',
#  '₹7,826/month',
#  '₹6,920/month',
#  '₹9,438/month',
#  '₹4,487/month',
#  '₹14,788/month',
#  '₹6,740/month',
#  '₹4,238/month',
#  '₹11,674/month',
#  '₹7,234/month',
#  '₹8,351/month',
#  '₹5,837/month',
#  '₹7,754/month',
#  '₹8,424/month',
#  '₹6,994/month',
#  '₹10,281/month',
#  '₹6,208/month',
#  '₹7,461/month',
#  '₹8,128/month',
#  '₹5,214/month',
#  '₹14,254/month',
#  '₹13,035/month',
#  '₹6,506/month',
#  '₹6,627/month',
#  '₹3,159/month',
#  '₹9,427/month',
#  '₹6,940/month',
#  '₹6,629/month',
#  '₹4,480/month',
#  '₹8,606/month',
#  '₹14,592/month',
#  '₹5,679/month',
#  '₹5,519/month',
#  '₹8,664/month',
#  '₹4,967/month',
# ...

# %%
len(carnames)
# Out:
# 2342

# %%
len(acc)
# Out:
# 2342

# %%
len(loc)
# Out:
# 2342

# %%
len(fuel)
# Out:
# 2342

# %%
len(yop)
# Out:
# 2342

# %%
len(owner)
# Out:
# 2342

# %%
len(km)
# Out:
# 2342

# %%
len(rto)
# Out:
# 2342

# %%
len(emiprice)
# Out:
# 2342

# %%
len(carnames)
# Out:
# 2342

# %%
acc
# Out:
# ['Non-Accidental',
#  'Non-Accidental',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  '-',
#  '-',
#  'Non-Accidental',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
# ...

# %%
acc
# Out:
# ['Non-Accidental',
#  'Non-Accidental',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  '-',
#  '-',
#  'Non-Accidental',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  '-',
#  'Non-Accidental',
#  'Non-Accidental',
# ...

# %%
len(acc)
# Out:
# 2342

# %%
driver=webdriver.Chrome(r"C:\Users\ChesthaS\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
url = "https://www.cars24.com/buy-used-cars-Delhi/?itm_source=Cars24Website&itm_medium=sticky_header"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
driver.get(url)

# %%
carurls_tag=driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[4]/div[1]/div/div/a")
carurls_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7c22f652ccf1c48fff85f37dd8344d02", element="e1cbe2d4-fada-43f1-b36f-aab6b2c4c27c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7c22f652ccf1c48fff85f37dd8344d02", element="e5d7c3b7-82c9-48c0-a618-ac4a3afcb195")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7c22f652ccf1c48fff85f37dd8344d02", element="c882f49a-e27a-4bc0-9549-33a2593fc7c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7c22f652ccf1c48fff85f37dd8344d02", element="9d1d2b6f-ea3a-4174-8656-0f93d77fb255")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7c22f652ccf1c48fff85f37dd8344d02", element="7d34c162-53b6-48c7-8c29-cc851f24757f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7c22f652ccf1c48fff85f37dd8344d02", element="82ca6d9e-1777-4aff-ace3-5c323ecafb69")>,
# ...

# %%
len(carurls_tag)
# Out:
# 2315

# %%
carurls=[]
for i in carurls_tag:
    carurls.append(i.get_attribute('href'))

# %%
carurls
# Out:
# ['https://www.cars24.com/buy-used-Maruti-Alto-K10-2018-cars-New-Delhi-1009773240/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2014-cars-Faridabad-1057739946/',
#  'https://www.cars24.com/buy-used-Hyundai-Grand-i10-2014-cars-Faridabad-1052736921/',
#  'https://www.cars24.com/buy-used-Tata-Tiago-2018-cars-New-Delhi-1001740548/',
#  'https://www.cars24.com/buy-used-Tata-Nano-2016-cars-Noida-1002529209/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2013-cars-Noida-1059637240/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2015-cars-New-Delhi-1007649408/',
#  'https://www.cars24.com/buy-used-Maruti-Eeco-2017-cars-Gurgaon-1004628547/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2017-cars-New-Delhi-1017040545/',
#  'https://www.cars24.com/buy-used-Hyundai-Grand-i10-2018-cars-New-Delhi-1009644145/',
#  'https://www.cars24.com/buy-used-Maruti-Celerio-2016-cars-New-Delhi-1054631904/',
# ...

# %%
len(carurls)
# Out:
# 2315

# %%
carurls_list=carurls[:20]

# %%
for i in carurls_list:
    driver.get(i)
    time.sleep(5)
    try:
        carnames_tag=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2")
        carnames_p=carnames_tag.text
        print(carnames_p)
        carnames.append(carnames_p)
    except NoSuchElementException as e:
        print('-')
        carnames.append('-')
    try:
        emiprice_tag=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div/div/div[2]/div[1]/strong")
        emiprice_p=emiprice_tag.text
        print(emiprice_p)
        emiprice.append(emiprice_p)
    except NoSuchElementException as e:
        print('-')
        emiprice.append('-')     
    try:
        rto_tag=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div/div/div[1]/div[3]/strong")
        rto_p=rto_tag.text
        print(rto_p)
        rto.append(rto_p)
    except NoSuchElementException as e:
        print('-')
        rto.append('-')
    try:
        km_tag=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[3]/strong")
        km_p=km_tag.text
        print(km_p)
        km.append(km_p)
    except NoSuchElementException as e:
        print('-')
        km.append('-')
    try:
        owner_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[2]/strong")
        owner_p=owner_tags.text
        print(owner_p)
        owner.append(owner_p)
    except NoSuchElementException as e:
        print('-')
        owner.append('-')
    try:
        yop_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[8]/strong")
        yop_p=yop_tags.text
        print(yop_p)
        yop.append(yop_p)
    except NoSuchElementException as e:
        print('-')
        yop.append('-')
    try:
        fuel_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[4]/strong")
        fuel_p=fuel_tags.text
        print(fuel_p)
        fuel.append(fuel_p)
    except NoSuchElementException as e:
        print('-')
        fuel.append('-')
    try:
        loc_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[4]/div/div/div/div[1]/p/span")
        loc_p=loc_tags.text
        print(loc_p)
        loc.append(loc_p)
    except NoSuchElementException as e:
        print('-')
        loc.append('-')
    try:
        acc_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[1]/strong")
        acc_p=acc_tags.text
        print(acc_p)
        acc.append(acc_p)
    except NoSuchElementException as e:
        print('-')
        acc.append('-')
# Out:
# -
# -
# -
# 5,198 km
# 1st Owner
# September 2018
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 12,535 km
# 1st Owner
# March 2014
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 22,836 km
# 1st Owner
# August 2014
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 2,089 km
# 1st Owner
# June 2018
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 20,039 km
# 1st Owner
# -
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 26,908 km
# 1st Owner
# March 2013
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 17,637 km
# 1st Owner
# -
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 21,722 km
# 1st Owner
# April 2017
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 20,685 km
# 2nd Owner
# February 2017
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 15,754 km
# 2nd Owner
# June 2018
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 4,093 km
# 1st Owner
# -
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 19,104 km
# 1st Owner
# January 2020
# Petrol
# DELHI
# Non-Accidental
# -
# -
# -
# 49,654 km
# ...

# %%
cars=pd.DataFrame({})
cars['Name']=carnames
cars['EMI']=emiprice
cars['Price']=rto
cars['Kilometers Driven']=km
cars['Owner']=owner
cars['Year of Purchase']=yop
cars['Fuel Type']=fuel
cars['Location']=loc
cars['History']=acc

# %%
cars
# Out:
#                       Name            EMI      Price Kilometers Driven  \
# 0     2011 Maruti Alto K10   ₹4,734/month  ₹2,12,799         20,354 km
# 1        2020 Maruti Swift  ₹12,110/month  ₹5,44,399          6,623 km
# 2        2021 Maruti Swift  ₹17,017/month  ₹7,65,000                 -
# 3     2017 Maruti Alto 800   ₹6,535/month  ₹2,93,799          8,501 km
# 4     2012 Maruti Alto K10   ₹3,908/month  ₹1,75,699         42,321 km
# ...                    ...            ...        ...               ...
# 2357                     -              -          -                 -
# 2358                     -              -          -         11,961 km
# 2359                     -              -          -         15,750 km
# 2360                     -              -          -         25,360 km
# 2361                     -              -          -         27,915 km
#
#           Owner Year of Purchase Fuel Type Location         History
# ...

# %%
carurls_list=carurls[20:]

# %%
for i in carurls_list:
    driver.get(i)
    time.sleep(5)
    try:
        carnames_tag=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2")
        carnames_p=carnames_tag.text
        print(carnames_p)
        carnames.append(carnames_p)
    except NoSuchElementException as e:
        print('-')
        carnames.append('-')
    try:
        emiprice_tag=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div/div/div[2]/div[1]/strong")
        emiprice_p=emiprice_tag.text
        print(emiprice_p)
        emiprice.append(emiprice_p)
    except NoSuchElementException as e:
        print('-')
        emiprice.append('-')     
    try:
        rto_tag=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div/div/div[1]/div[3]/strong")
        rto_p=rto_tag.text
        print(rto_p)
        rto.append(rto_p)
    except NoSuchElementException as e:
        print('-')
        rto.append('-')
    try:
        km_tag=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[3]/strong")
        km_p=km_tag.text
        print(km_p)
        km.append(km_p)
    except NoSuchElementException as e:
        print('-')
        km.append('-')
    try:
        owner_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[2]/strong")
        owner_p=owner_tags.text
        print(owner_p)
        owner.append(owner_p)
    except NoSuchElementException as e:
        print('-')
        owner.append('-')
    try:
        yop_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[8]/strong")
        yop_p=yop_tags.text
        print(yop_p)
        yop.append(yop_p)
    except NoSuchElementException as e:
        print('-')
        yop.append('-')
    try:
        fuel_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[4]/strong")
        fuel_p=fuel_tags.text
        print(fuel_p)
        fuel.append(fuel_p)
    except NoSuchElementException as e:
        print('-')
        fuel.append('-')
    try:
        loc_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[4]/div/div/div/div[1]/p/span")
        loc_p=loc_tags.text
        print(loc_p)
        loc.append(loc_p)
    except NoSuchElementException as e:
        print('-')
        loc.append('-')
    try:
        acc_tags=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[1]/strong")
        acc_p=acc_tags.text
        print(acc_p)
        acc.append(acc_p)
    except NoSuchElementException as e:
        print('-')
        acc.append('-')
# Out:
# 2017 Maruti Alto 800 VXI MANUAL
# ₹6,306/month
# ₹2,94,299₹2,71,299
# 5,636 km
# 2nd Owner
# December 2017
# Petrol
# DELHI
# Non-Accidental
# 2018 Datsun Redi Go T MANUAL
# ₹5,905/month
# ₹2,62,699₹2,53,699
# 15,468 km
# 1st Owner
# Valid upto Oct 2022
# 3rd Party
# Petrol
# DELHI
# Non-Accidental
# 2018 Maruti Swift LXI MANUAL
# ₹10,652/month
# ₹4,92,199₹4,62,199
# 12,268 km
# 1st Owner
# Valid upto Oct 2022
# 3rd Party
# Petrol
# DELHI
# Non-Accidental
# 2014 Maruti Swift VXI MANUAL
# ₹9,505/month
# ₹4,44,799₹4,11,799
# 13,509 km
# 2nd Owner
# May 2014
# Petrol
# DELHI
# Non-Accidental
# 2020 Renault TRIBER RXZ AT AUTOMATIC
# ₹14,847/month
# ₹6,52,399₹6,46,399
# 6,460 km
# 1st Owner
# Valid upto Oct 2022
# 3rd Party
# Petrol
# DELHI
# Non-Accidental
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-100-52f7127c600e> in <module>
# ...

# %%
len(carnames)
# Out:
# 2572

# %%
len(acc)
# Out:
# 2572

# %%
print(len(emiprice))
print(len(rto))
print(len(owner))
print(len(km))
print(len(yop))
print(len(fuel))
print(len(loc))
# Out:
# 2572
# 2572
# 2572
# 2572
# 2572
# 2572
# 2572

# %%
cars=pd.DataFrame({})
cars['Name']=carnames
cars['EMI']=emiprice
cars['Price']=rto
cars['Kilometers Driven']=km
cars['Owner']=owner
cars['Year of Purchase']=yop
cars['Fuel Type']=fuel
cars['Location']=loc
cars['History']=acc

# %%
cars
# Out:
#                                       Name            EMI               Price  \
# 0                     2011 Maruti Alto K10   ₹4,734/month           ₹2,12,799
# 1                        2020 Maruti Swift  ₹12,110/month           ₹5,44,399
# 2                        2021 Maruti Swift  ₹17,017/month           ₹7,65,000
# 3                     2017 Maruti Alto 800   ₹6,535/month           ₹2,93,799
# 4                     2012 Maruti Alto K10   ₹3,908/month           ₹1,75,699
# ...                                    ...            ...                 ...
# 2567       2017 Maruti Alto 800 VXI MANUAL   ₹6,306/month  ₹2,94,299₹2,71,299
# 2568          2018 Datsun Redi Go T MANUAL   ₹5,905/month  ₹2,62,699₹2,53,699
# 2569          2018 Maruti Swift LXI MANUAL  ₹10,652/month  ₹4,92,199₹4,62,199
# 2570          2014 Maruti Swift VXI MANUAL   ₹9,505/month  ₹4,44,799₹4,11,799
# 2571  2020 Renault TRIBER RXZ AT AUTOMATIC  ₹14,847/month  ₹6,52,399₹6,46,399
#
# ...

# %%
cars.to_csv('cars.csv')
